# %% [markdown]
# # 13__fimo_v_mind
# # comparing ChIP overlap b/w FIMO and MIND
#
# in this notebook, i ...
#
# **NOTE: .**
#
# ------
#
# figures in this notebook:
# -

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import time

from os import walk
from scipy.stats import spearmanr

# import utils
sys.path.append("../../utils")
from plotting_utils import *
from misc_utils import *
from norm_utils import *

# %matplotlib inline

# %%
sns.set(**PAPER_PRESET)
fontsize = PAPER_FONTSIZE

# %% [markdown]
# ## variables

# %%
chip_dir = "../../misc/9__chip_data"

# %%
hepg2_motif_dir = "../../data/06__mind_results/HepG2/files/1__motif_scores"
k562_motif_dir = "../../data/06__mind_results/K562/files/1__motif_scores"

# %%
fimo_f = "../../misc/05__fimo/pool2.fimo.txt"

# %%
del_buffer = 10
fdr_cutoff = 0.05

# %% [markdown]
# ## 1. import data

# %%
hepg2_files = []
for (dirpath, dirnames, filenames) in walk(hepg2_motif_dir):
    hepg2_files.extend(filenames)
    break
hepg2_files = [x for x in hepg2_files if "loss__results" in x and "expr_filt" not in x]
hepg2_files[0:5]
# Out:
# ['enhancer_NEAT1__pX__tile2__minus__peak1.loss__results.txt',
#  'enhancer_NEAT1__pX__tile2__minus__peak2.loss__results.txt',
#  'enhancer_MALAT1__pX__tile2__minus__peak1.loss__results.txt',
#  'enhancer_MALAT1__pX__tile2__minus__peak2.loss__results.txt',
#  'enhancer_MALAT1__pX__tile2__minus__peak3.loss__results.txt']

# %%
k562_files = []
for (dirpath, dirnames, filenames) in walk(k562_motif_dir):
    k562_files.extend(filenames)
    break
k562_files = [x for x in k562_files if "loss__results" in x and "expr_filt" not in x]
k562_files[0:5]
# Out:
# ['enhancer_MALAT1__pX__tile1__minus__peak1.loss__results.txt',
#  'enhancer_MALAT1__pX__tile2__minus__peak1.loss__results.txt',
#  'enhancer_MALAT1__pX__tile2__minus__peak2.loss__results.txt',
#  'FALEC__p1__tile2__plus__peak1.loss__results.txt',
#  'GAS5__p1__tile2__minus__peak1.loss__results.txt']

# %%
fimo = pd.read_table(fimo_f, sep="\t")
fimo.head()
# Out:
#   #pattern name                                      sequence name  start  \
# 0        ZNF263  WILDTYPE_BUT_HAS_SNP_DELETION__Lincrna.noflip....     39
# 1        ZNF263  WILDTYPE_SNP_INDIV__mrna.noflip.NA__p1@IRX5__c...     24
# 2         RREB1  WILDTYPE_BUT_HAS_SNP_DELETION__mrna.flip.sense...     24
# 3         RREB1  FLIPPED_DELETION__mrna.flip.antisense__p1@CDKN...     71
# 4        ZNF263  WILDTYPE_BUT_HAS_SNP_DELETION__Lincrna.noflip....     38
#
#    stop strand    score       p-value   q-value       matched sequence
# 0    59      -  27.0204  4.070000e-11  0.000024  GGAGGAGGGAGGGGAGGGGAG
# 1    44      +  26.6735  6.730000e-11  0.000024  GGAGGAGGAAGAGGGAGAGGG
# 2    43      -  27.0550  3.310000e-10  0.000043   CCCCACCCCACCCCCACCCC
# 3    90      +  27.0550  3.310000e-10  0.000043   CCCCACCCCACCCCCACCCC
# 4    58      -  25.3878  3.590000e-10  0.000024  GAGGGAGGGAGGGGAGGGGGG

# %% [markdown]
# ## 2. find motifs < 0.05 FDR & put in terms of absolute coords

# %%
hepg2_data = {}
for f in hepg2_files:
    name = f.split(".")[0]
    df = pd.read_table("%s/%s" % (hepg2_motif_dir, f), sep="\t")
    hepg2_data[name] = df
    #print("%s: min motif nuc: %s, max motif nuc: %s" % (name, df["start"].min(), df["end"].max()))
hepg2_data["GAS5__p1__tile2__minus__peak1"].head()
# Out:
#    motif  start  end     score    pval tile_chr   tile_start     tile_end  \
# 0  CREB1     20   28  6.794534  0.0001     chr1  173837092.0  173837206.0
# 1  Gmeb1     15   32  6.216823  0.0020     chr1  173837092.0  173837206.0
# 2  Creb5     18   30  6.029732  0.0001     chr1  173837092.0  173837206.0
# 3   Atf3     22   30  6.001356  0.0001     chr1  173837092.0  173837206.0
# 4   Crem     20   30  5.974204  0.0001     chr1  173837092.0  173837206.0
#
#       strand      padj  neg_log_pval  fdr_cutoff
# 0  antisense  0.002256      2.646604        0.05
# 1  antisense  0.020562      1.686933        0.05
# 2  antisense  0.002256      2.646604        0.05
# 3  antisense  0.002256      2.646604        0.05
# 4  antisense  0.002256      2.646604        0.05

# %%
k562_data = {}
for f in k562_files:
    name = f.split(".")[0]
    df = pd.read_table("%s/%s" % (k562_motif_dir, f), sep="\t")
    k562_data[name] = df
    #print("%s: min motif nuc: %s, max motif nuc: %s" % (name, df["start"].min(), df["end"].max()))
k562_data["GAS5__p1__tile2__minus__peak1"].head()
# Out:
#    motif  start  end     score    pval tile_chr   tile_start     tile_end  \
# 0  CREB1     20   28  6.356575  0.0001     chr1  173837092.0  173837206.0
# 1  Gmeb1     15   32  5.702321  0.0028     chr1  173837092.0  173837206.0
# 2  Creb5     18   30  5.651505  0.0001     chr1  173837092.0  173837206.0
# 3   Atf3     22   30  5.539003  0.0001     chr1  173837092.0  173837206.0
# 4   ATF7     17   31  5.538545  0.0001     chr1  173837092.0  173837206.0
#
#       strand      padj  neg_log_pval  fdr_cutoff
# 0  antisense  0.003707      2.431004        0.05
# 1  antisense  0.044032      1.356232        0.05
# 2  antisense  0.003707      2.431004        0.05
# 3  antisense  0.003707      2.431004        0.05
# 4  antisense  0.003707      2.431004        0.05

# %%
def get_strand(row):
    if row["strand"] == "sense":
        return "+"
    else:
        return "-"

# %%
hepg2_all_motifs = pd.DataFrame()
hepg2_top5_motifs = pd.DataFrame()
for name in hepg2_data:
    df = hepg2_data[name]

    if "plus" in name:
        df["motif_start"] = df["tile_start"].astype(int) + del_buffer + df["start"].astype(int) - 1
        df["motif_end"] = df["tile_start"].astype(int) + del_buffer + df["start"].astype(int) + (df["end"]-df["start"]).astype(int) - 1
    elif "minus" in name:
        df["motif_end"] = df["tile_end"].astype(int) - del_buffer - df["start"].astype(int) + 1
        df["motif_start"] = df["motif_end"].astype(int) - (df["end"]-df["start"]).astype(int)
        
    # limit to motifs < fdr cutoff
    sig_motifs = df[df["padj"] < 0.05]
    sig_motifs["gene"] = name
    sig_motifs["id"] = sig_motifs["motif"].astype(str) + "__" + sig_motifs["tile_chr"].astype(str) + "__" + sig_motifs["motif_start"].astype(str)
    
    # for other analysis - limit to top 5
    top5_motifs = sig_motifs.sort_values(by="score", ascending=False).head(5)
    
    hepg2_all_motifs = hepg2_all_motifs.append(sig_motifs)
    hepg2_top5_motifs = hepg2_top5_motifs.append(top5_motifs)

hepg2_all_motifs["strand"] = hepg2_all_motifs.apply(get_strand, axis=1)
hepg2_all_motifs = hepg2_all_motifs[["tile_chr", "motif_start", "motif_end", "motif", "score", "strand", "gene", "id"]]
hepg2_all_motifs = hepg2_all_motifs.drop_duplicates()
hepg2_all_motifs.sample(5)
# Out:
#     tile_chr  motif_start  motif_end  motif     score strand  \
# 24      chr1    173837164  173837174  MEOX2  4.058077      +
# 22      chr3     70048833   70048843   Klf4  3.769088      -
# 12      chr1    173837492  173837502   ELK3  6.497602      -
# 111     chr1    173837169  173837177    Id2  2.426313      +
# 15      chr1    173837169  173837177  GMEB2  4.760499      +
#
#                                 gene                      id
# 24     GAS5__p1__tile2__minus__peak1  MEOX2__chr1__173837164
# 22   SAMMSON__p1__tile2__plus__peak1    Klf4__chr3__70048833
# 12    ZBTB37__p1__tile2__plus__peak3   ELK3__chr1__173837492
# 111    GAS5__p1__tile2__minus__peak1    Id2__chr1__173837169
# 15     GAS5__p1__tile2__minus__peak1  GMEB2__chr1__173837169

# %%
k562_all_motifs = pd.DataFrame()
k562_top5_motifs = pd.DataFrame()

for name in k562_data:
    df = k562_data[name]

    if "plus" in name:
        df["motif_start"] = df["tile_start"].astype(int) + del_buffer + df["start"].astype(int) - 1
        df["motif_end"] = df["tile_start"].astype(int) + del_buffer + df["start"].astype(int) + (df["end"]-df["start"]).astype(int) - 1
    elif "minus" in name:
        df["motif_end"] = df["tile_end"].astype(int) - del_buffer - df["start"].astype(int) + 1
        df["motif_start"] = df["motif_end"].astype(int) - (df["end"]-df["start"]).astype(int)
        
    # limit to motifs < 0.05
    sig_motifs = df[df["padj"] < 0.05]
    sig_motifs["gene"] = name
    sig_motifs["id"] = sig_motifs["motif"].astype(str) + "__" + sig_motifs["tile_chr"].astype(str) + "__" + sig_motifs["motif_start"].astype(str)
    
    # for other analysis - limit to top 5
    top5_motifs = sig_motifs.sort_values(by="score", ascending=False).head(5)
    
    k562_all_motifs = k562_all_motifs.append(sig_motifs)
    k562_top5_motifs = k562_top5_motifs.append(top5_motifs)

k562_all_motifs["strand"] = k562_all_motifs.apply(get_strand, axis=1)
k562_all_motifs = k562_all_motifs[["tile_chr", "motif_start", "motif_end", "motif", "score", "strand", "gene", "id"]]
k562_all_motifs = k562_all_motifs.drop_duplicates()
k562_all_motifs.sample(5)
# Out:
#    tile_chr  motif_start  motif_end          motif     score strand  \
# 17     chr3    169482983  169482993           ETV6  4.634987      +
# 33     chr3     70048833   70048844       MAX::MYC  3.010900      -
# 13    chr14    101292391  101292405          BATF3  3.515244      +
# 10     chr5     90610261   90610269           Pax2  5.744323      +
# 45     chr1    173837168  173837178  SREBF2(var.2)  2.797089      -
#
#                                gene                              id
# 17    TERC__p1__tile1__minus__peak1           ETV6__chr3__169482983
# 33  SAMMSON__p1__tile2__plus__peak1        MAX::MYC__chr3__70048833
# 13     MEG3__p1__tile2__plus__peak1         BATF3__chr14__101292391
# 10  LUCAT1__p1__tile2__minus__peak1            Pax2__chr5__90610261
# 45    GAS5__p1__tile2__minus__peak1  SREBF2(var.2)__chr1__173837168

# %%
hepg2_all_motifs["cell_type"] = "HepG2"
k562_all_motifs["cell_type"] = "K562"
all_motifs = hepg2_all_motifs.append(k562_all_motifs)

# %%
len(all_motifs)
# Out:
# 832

# %% [markdown]
# ## same for fimo

# %%
fimo_wt = fimo[~(fimo["sequence name"].str.contains("DELETION")) & 
               ~(fimo["sequence name"].str.contains("SNP_INDIV"))]
fimo_wt.sample(5)
# Out:
#       #pattern name                                      sequence name  start  \
# 5766           ELF4  WILDTYPE_BUT_HAS_SNP__mrna.noflip.NA__p1@ZBTB3...     55
# 47281          KLF5  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p4@MA...     29
# 8696         ZNF263  WILDTYPE_BUT_HAS_SNP__Enhancer.noflip.NA__chr1...     25
# 22219           SP2  FLIPPED__mrna.flip.antisense__p1@CDKN2A__chr9:...     70
# 8146           HIC2  CONTROL_BUT_HAS_SNP__control.noflip.NA__p1@S10...      5
#
#        stop strand    score   p-value  q-value       matched sequence
# 5766     66      -  17.0656  0.000001  0.01880           GTCCCGGAAGTG
# 47281    38      +  13.0204  0.000028  0.01030             GTCCCTCCCC
# 8696     45      +  15.4694  0.000002  0.00148  GGGAGAGCGGGGGCGGGGAGG
# 22219    84      +  14.1552  0.000009  0.00357        CCCCCACCCCACCCC
# 8146     13      +  12.8909  0.000002  0.37100              GTGCCCACC

# %%
fimo_wt = fimo_wt.merge(index[["unique_id", "chr", "tile_start", "tile_end"]].drop_duplicates(), 
                        left_on="sequence name", right_on="unique_id")
fimo_wt.sample(5)
# Out:
#      #pattern name                                      sequence name  start  \
# 152            SP3  FLIPPED__mrna.flip.antisense__p1@CDKN2A__chr9:...     66
# 1537         Gmeb1  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...     16
# 1598         MEF2D  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@MA...     20
# 396           FLI1  WILDTYPE_BUT_HAS_SNP__mrna.noflip.NA__p1@ZBTB3...     55
# 1566         THAP1  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@NE...     54
#
#       stop strand     score   p-value  q-value   matched sequence  \
# 152     76      +  12.85370  0.000019  0.00931        CCCACCCCCAC
# 1537    32      +  12.38160  0.000005  0.05740  GCGCTGACGTCAGAGAC
# 1598    31      -   6.92727  0.000062  0.31100       GTTAAAAATAGG
# 396     64      -  12.36170  0.000033  0.12100         CCCGGAAGTG
# 1566    62      -  11.34210  0.000010  0.06940          CTGCCCGGA
#
#                                               unique_id    chr   tile_start  \
# 152   FLIPPED__mrna.flip.antisense__p1@CDKN2A__chr9:...   chr9   21994446.0
# 1537  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...  chr14  101292375.0
# 1598  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@MA...  chr11   65266377.0
# 396   WILDTYPE_BUT_HAS_SNP__mrna.noflip.NA__p1@ZBTB3...   chr1  173837438.0
# 1566  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@NE...  chr11   65190095.0
#
#          tile_end
# 152    21994560.0
# 1537  101292489.0
# 1598   65266491.0
# 396   173837552.0
# 1566   65190209.0

# %%
fimo_wt["motif_start"] = fimo_wt["tile_start"].astype(int) + fimo_wt["start"].astype(int) - 1
fimo_wt["motif_end"] = fimo_wt["tile_start"].astype(int) + fimo_wt["stop"].astype(int)
fimo_wt["id"] = fimo_wt["#pattern name"] + "__" + fimo_wt["chr"] + "__" + fimo_wt["motif_start"].astype(str)
fimo_wt.sample(5)
# Out:
#      #pattern name                                      sequence name  start  \
# 1273          SPIB  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...     61
# 231            SP2  WILDTYPE_BUT_HAS_SNP__mrna.flip.sense__p1@CDKN...     56
# 810         TFAP2A  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...     33
# 334          NR2C2  WILDTYPE_BUT_HAS_SNP__mrna.flip.sense__p1@CDKN...     46
# 1652          IRF1  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...     20
#
#       stop strand     score       p-value  q-value       matched sequence  \
# 1273    67      +  11.23330  6.510000e-05  0.13800                AGAGGAA
# 231     70      -  17.08620  8.470000e-07  0.00122        CGCCCGCCCCCCACC
# 810     43      +  13.80000  9.990000e-06  0.01620            CGCCTCGGGCT
# 334     60      +   8.71429  8.910000e-05  0.08230        TGGGGGTGAAGGTGG
# 1652    40      -   8.58065  7.870000e-05  0.17600  TTTTTGTTTTTGTTTTTGGTG
#
#                                               unique_id    chr   tile_start  \
# 1273  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...   chr1  173837186.0
# 231   WILDTYPE_BUT_HAS_SNP__mrna.flip.sense__p1@CDKN...   chr9   21994446.0
# 810   WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...  chr20   47895005.0
# 334   WILDTYPE_BUT_HAS_SNP__mrna.flip.sense__p1@CDKN...   chr9   21994446.0
# 1652  WILDTYPE_BUT_HAS_SNP__Antisense.noflip.NA__p1@...  chr12   54362514.0
#
#          tile_end  motif_start  motif_end                       id
# 1273  173837300.0    173837246  173837253    SPIB__chr1__173837246
# 231    21994560.0     21994501   21994516      SP2__chr9__21994501
# 810    47895119.0     47895037   47895048  TFAP2A__chr20__47895037
# 334    21994560.0     21994491   21994506    NR2C2__chr9__21994491
# 1652   54362628.0     54362533   54362554    IRF1__chr12__54362533

# %%
fimo_bed = fimo_wt[["chr", "motif_start", "motif_end", "#pattern name", "score", "strand", "sequence name", "id"]]
fimo_bed.columns = ["tile_chr", "motif_start", "motif_end", "motif", "score", "strand", "gene", "id"]
fimo_bed.head()
# Out:
#   tile_chr  motif_start  motif_end   motif    score strand  \
# 0     chr1    211556009  211556030  ZNF263  23.8367      -
# 1     chr1    211556005  211556026  ZNF263  22.1429      -
# 2     chr1    211556000  211556015     SP2  18.7241      +
# 3     chr1    211556000  211556021  ZNF263  18.4082      -
# 4     chr1    211556000  211556011     SP1  16.7692      +
#
#                                                 gene                       id
# 0  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@LI...  ZNF263__chr1__211556009
# 1  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@LI...  ZNF263__chr1__211556005
# 2  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@LI...     SP2__chr1__211556000
# 3  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@LI...  ZNF263__chr1__211556000
# 4  WILDTYPE_BUT_HAS_SNP__Lincrna.noflip.NA__p1@LI...     SP1__chr1__211556000

# %%
len(fimo_bed)
# Out:
# 1759

# %%
# make df w/ a cell column
# since fimo = same across cell types, obviously, just repeat df
hepg2_fimo = fimo_bed.copy()
hepg2_fimo["cell_type"] = "HepG2"
k562_fimo = fimo_bed.copy()
k562_fimo["cell_type"] = "K562"
all_fimo = hepg2_fimo.append(k562_fimo)

# %% [markdown]
# ## 3. intersect w/ bed files for cell type

# %%
chip_files = []
for (dirpath, dirnames, filenames) in walk(chip_dir):
    chip_files.extend(filenames)
    break

chip_files = [x for x in chip_files if "__" in x]
hepg2_chip_files = [x for x in chip_files if "HepG2" in x]
k562_chip_files = [x for x in chip_files if "K562" in x]
k562_chip_files[0:5]
# Out:
# ['K562__ARID3A__narrowPeak_clean.bed.gz',
#  'K562__ATF1__narrowPeak_clean.bed.gz',
#  'K562__ATF3__narrowPeak_clean.bed.gz',
#  'K562__BACH1__narrowPeak_clean.bed.gz',
#  'K562__BCL3__narrowPeak_clean.bed.gz']

# %%
print("total chip files: %s" % (len(chip_files)))
print("total HepG2 chip files: %s" % (len(hepg2_chip_files)))
print("total K562 chip files: %s" % (len(k562_chip_files)))
# Out:
# total chip files: 539
# total HepG2 chip files: 59
# total K562 chip files: 100

# %%
hepg2_chip_motifs = [x.split("__")[1].upper() for x in hepg2_chip_files]
k562_chip_motifs = [x.split("__")[1].upper() for x in k562_chip_files]
chip_motifs = [x.split("__")[1].upper() for x in chip_files]
chip_motifs[0:5]
# Out:
# ['ATF3', 'BCL3', 'BHLHE40', 'CEBPB', 'CREB1']

# %%
uniq_motifs = sorted(list(all_motifs["motif"].unique()))
len(uniq_motifs)
# Out:
# 277

# %%
def get_overlap(row, int_ids):
    if row["id"] in int_ids:
        return "ChIP_overlap"
    else:
        return "no_overlap"

# %%
def intersect_chip_files(sub_df, chip_filename, colname):
    sub_df.to_csv("tmp.motifs.bed", sep="\t", index=False, header=False)
    # !bedtools intersect -u -a tmp.motifs.bed -b $chip_filename > tmp.txt
    
    try:
        results = pd.read_table("tmp.txt", sep="\t", header=None)
        int_ids = list(results[7])
        sub_df[colname] = sub_df.apply(get_overlap, int_ids=int_ids, axis=1)
    except:
        sub_df[colname] = "no_overlap"
    return sub_df

# %%
def merge_and_intersect_chip_files(chip_files, motif, chip_dir, sub_df, colname):
    chip_files_sub = [x for x in chip_files if motif in x]
    chip_paths = ["%s/%s" % (chip_dir, x) for x in chip_files_sub]
    all_chip = pd.DataFrame()
    for f in chip_paths:
        tmp = pd.read_table(f, sep="\t", header=None)
        all_chip = all_chip.append(tmp)
    all_chip.to_csv("tmp.chip.bed", sep="\t", header=False, index=False)

    # intersect bed files
    sub_df = intersect_chip_files(sub_df, "tmp.chip.bed", colname)
    return sub_df

# %%
all_motifs_int = pd.DataFrame()
n_chip = 0
n_cell_chip = 0

for motif in uniq_motifs:
    print("=== %s ===" % motif)
    sub_df = all_motifs[all_motifs["motif"] == motif]
    
    # first check if these motifs overlap *any* chip peaks
    # sub_df = intersect_chip_files(sub_df, "%s/all.chip.bed.gz" % chip_dir, "any_chip_overlap")
    
    # force motif to upper
    motif_up = motif.upper()
    
    # see if that motif has been chipped at all
    if motif_up in chip_motifs:
        print("has been chipped")
        n_chip += 1

        sub_df = merge_and_intersect_chip_files(chip_files, motif_up, chip_dir, sub_df, "all_chip_overlap")
            
        # do both k562 & hepg2
        for cell, cell_chip_motifs, cell_chip_files in zip(["HepG2", "K562"], [hepg2_chip_motifs, k562_chip_motifs], [hepg2_chip_files, k562_chip_files]):
            cell_df = sub_df[sub_df["cell_type"] == cell]

            # now see if that motif has been chipped in cell type
            if motif_up in cell_chip_motifs:
                print("in %s" % cell)
                n_cell_chip += 1

                # find chip files and merge again
                cell_df = merge_and_intersect_chip_files(cell_chip_files, motif_up, chip_dir, cell_df, 
                                                        "cell_chip_overlap")
            else:
                cell_df["cell_chip_overlap"] = "no_ChIP"
            
            all_motifs_int = all_motifs_int.append(cell_df)
    else:
        sub_df["all_chip_overlap"] = "no_ChIP"
        sub_df["cell_chip_overlap"] = "no_ChIP"
        all_motifs_int = all_motifs_int.append(sub_df)
# Out:
# === ARNT::HIF1A ===
# === ATF4 ===
# === ATF7 ===
# === Ahr::Arnt ===
# === Arid3a ===
# has been chipped
# in HepG2
# in K562
# === Arid5a ===
# === Arnt ===
# === Arntl ===
# === Ascl2 ===
# === Atf1 ===
# has been chipped
# in K562
# === Atf3 ===
# has been chipped
# in HepG2
# in K562
# === BARHL2 ===
# === BATF3 ===
# === BATF::JUN ===
# === BHLHE40 ===
# has been chipped
# in HepG2
# in K562
# === BHLHE41 ===
# === Bach1::Mafk ===
# === Barhl1 ===
# === Bcl6 ===
# === CDX1 ===
# === CDX2 ===
# === CEBPB ===
# has been chipped
# in HepG2
# in K562
# === CEBPD ===
# has been chipped
# in HepG2
# === CEBPE ===
# === CEBPG ===
# === CREB1 ===
# has been chipped
# === CREB3 ===
# === CREB3L1 ===
# === Creb3l2 ===
# === Creb5 ===
# === Crem ===
# === DBP ===
# === DLX6 ===
# === DUX4 ===
# === DUXA ===
# === Dlx3 ===
# === Dlx4 ===
# === Dux ===
# === E2F4 ===
# has been chipped
# in K562
# === E2F6 ===
# has been chipped
# in K562
# === E2F7 ===
# === E2F8 ===
# === EGR1 ===
# has been chipped
# in K562
# === EGR2 ===
# === EGR3 ===
# === EGR4 ===
# === EHF ===
# === ELF1 ===
# has been chipped
# in HepG2
# in K562
# === ELF3 ===
# === ELF4 ===
# === ELF5 ===
# === ELK1 ===
# has been chipped
# in K562
# === ELK3 ===
# === ELK4 ===
# has been chipped
# === EMX2 ===
# === EN1 ===
# === EN2 ===
# === ERF ===
# === ERG ===
# === ESR2 ===
# === ETS1 ===
# has been chipped
# in K562
# === ETV1 ===
# === ETV2 ===
# === ETV3 ===
# === ETV4 ===
# === ETV5 ===
# === ETV6 ===
# === FEV ===
# === FIGLA ===
# === FLI1 ===
# === FOS ===
# has been chipped
# in K562
# === FOS::JUN ===
# === FOSL1 ===
# has been chipped
# in K562
# === FOSL2 ===
# has been chipped
# in HepG2
# === FOXC2 ===
# === FOXD1 ===
# === FOXD2 ===
# === FOXF2 ===
# === FOXG1 ===
# === FOXI1 ===
# === FOXL1 ===
# === FOXO3 ===
# === FOXO4 ===
# === FOXO6 ===
# === Foxa2 ===
# has been chipped
# in HepG2
# === Foxj2 ===
# === Foxj3 ===
# === Foxk1 ===
# === Foxo1 ===
# === GATA3 ===
# has been chipped
# === GATA5 ===
# === GBX2 ===
# === GLI2 ===
# === GLIS3 ===
# === GMEB2 ===
# === GSX1 ===
# === GSX2 ===
# === Gabpa ===
# has been chipped
# in HepG2
# in K562
# === Gata4 ===
# === Gfi1 ===
# === Gmeb1 ===
# === HES5 ===
# === HES7 ===
# === HESX1 ===
# === HEY1 ===
# === HEY2 ===
# === HINFP ===
# === HLF ===
# === HLTF ===
# === HOXA10 ===
# === HOXA13 ===
# === HOXA5 ===
# === HOXB13 ===
# === HOXB2 ===
# === HOXC10 ===
# === HOXC11 ===
# === HOXC12 ===
# === HOXD11 ===
# === HOXD12 ===
# === HOXD13 ===
# === HSF1 ===
# has been chipped
# in HepG2
# === HSF2 ===
# === HSF4 ===
# === Hes1 ===
# === Hoxa11 ===
# === Hoxd3 ===
# === Hoxd9 ===
# === ID4 ===
# === INSM1 ===
# === IRF1 ===
# has been chipped
# in K562
# === Id2 ===
# === JDP2 ===
# === JDP2(var.2) ===
# === JUN ===
# has been chipped
# in HepG2
# in K562
# === JUN(var.2) ===
# === JUNB ===
# has been chipped
# in K562
# === JUND ===
# has been chipped
# in HepG2
# in K562
# === JUND(var.2) ===
# === KLF13 ===
# === KLF14 ===
# === KLF16 ===
# === KLF5 ===
# === Klf1 ===
# === Klf12 ===
# === Klf4 ===
# === LBX2 ===
# === LHX2 ===
# === LHX6 ===
# === LHX9 ===
# === Lhx8 ===
# === MAF::NFE2 ===
# === MAFF ===
# has been chipped
# in HepG2
# in K562
# === MAFG ===
# === MAFG::NFE2L1 ===
# === MAFK ===
# has been chipped
# in HepG2
# in K562
# === MAX ===
# has been chipped
# in HepG2
# in K562
# === MAX::MYC ===
# === MEF2C ===
# has been chipped
# === MEIS1 ===
# === MEIS3 ===
# === MEOX2 ===
# === MGA ===
# === MLX ===
# === MLXIPL ===
# === MNT ===
# === MNX1 ===
# === MSX1 ===
# === MSX2 ===
# === MTF1 ===
# === MYBL1 ===
# === Mafb ===
# === Mecom ===
# === Mitf ===
# === Mlxip ===
# === Msx3 ===
# === Myb ===
# === Myc ===
# has been chipped
# in HepG2
# in K562
# === Mycn ===
# === Myod1 ===
# === Myog ===
# === NFAT5 ===
# === NFATC1 ===
# has been chipped
# === NFATC2 ===
# === NFATC3 ===
# === NFE2 ===
# has been chipped
# in K562
# === NFIC ===
# has been chipped
# in HepG2
# === NFIL3 ===
# === NFIX ===
# === NFYA ===
# has been chipped
# in K562
# === NFYB ===
# has been chipped
# in K562
# === NHLH1 ===
# === NKX2-8 ===
# === NKX6-1 ===
# === NOTO ===
# === NR2C2 ===
# has been chipped
# in HepG2
# in K562
# === NR4A2 ===
# === NRF1 ===
# has been chipped
# in HepG2
# in K562
# === NRL ===
# === Nfe2l2 ===
# === Nobox ===
# === Npas2 ===
# === Nr2e1 ===
# === OTX1 ===
# === PAX4 ===
# === PBX1 ===
# === PKNOX1 ===
# === PKNOX2 ===
# === POU6F2 ===
# === PPARG ===
# === PRDM1 ===
# has been chipped
# === PROX1 ===
# === Pax2 ===
# === Prrx2 ===
# === RARA::RXRA ===
# === RAX ===
# === RAX2 ===
# === REL ===
# === RELA ===
# has been chipped
# === RFX4 ===
# === RORA ===
# === Rarg(var.2) ===
# === Rfx1 ===
# === SHOX ===
# === SNAI2 ===
# === SOX10 ===
# === SP1 ===
# has been chipped
# in HepG2
# in K562
# === SP2 ===
# has been chipped
# in HepG2
# in K562
# === SP3 ===
# === SP4 ===
# has been chipped
# === SP8 ===
# === SPDEF ===
# === SPI1 ===
# has been chipped
# in K562
# === SPIB ===
# === SPIC ===
# === SREBF1 ===
# === SREBF2 ===
# === SREBF2(var.2) ===
# === SRF ===
# has been chipped
# in HepG2
# in K562
# === STAT1 ===
# has been chipped
# in K562
# === STAT1::STAT2 ===
# === STAT3 ===
# has been chipped
# === Sox17 ===
# === Srebf1(var.2) ===
# === Stat4 ===
# === Stat5a::Stat5b ===
# === Stat6 ===
# === TBP ===
# has been chipped
# in HepG2
# in K562
# === TBR1 ===
# === TBX1 ===
# === TBX15 ===
# === TBX21 ===
# === TBX4 ===
# === TBX5 ===
# === TCF3 ===
# has been chipped
# === TCF4 ===
# === TCF7L2 ===
# has been chipped
# in HepG2
# === TEAD1 ===
# === TEAD3 ===
# === TEAD4 ===
# has been chipped
# in HepG2
# in K562
# === TEF ===
# === TFE3 ===
# === TFEB ===
# === TFEC ===
# === THAP1 ===
# has been chipped
# in K562
# === Tcf12 ===
# has been chipped
# in HepG2
# === Tcf7 ===
# === Tcfl5 ===
# === USF1 ===
# has been chipped
# in HepG2
# in K562
# === USF2 ===
# has been chipped
# in HepG2
# in K562
# === VSX2 ===
# === XBP1 ===
# === YY2 ===
# === ZBTB33 ===
# has been chipped
# in HepG2
# in K562
# === ZEB1 ===
# has been chipped
# === ZNF263 ===
# has been chipped
# in K562
# === ZNF354C ===
# === Zfx ===

# %%
all_motifs_int[all_motifs_int["motif"] == "NRF1"]
# Out:
#   tile_chr  motif_start  motif_end motif     score strand  \
# 0    chr20     47895120   47895131  NRF1  9.380756      -
# 8    chr13     50656376   50656387  NRF1  0.956409      +
# 1    chr13     50656265   50656276  NRF1  5.437629      +
# 3     chr1    211556129  211556140  NRF1  4.725896      +
# 0     chr1    150488212  150488223  NRF1  7.971965      -
# 0    chr20     47895120   47895131  NRF1  7.273011      -
#
#                                 gene                     id cell_type  \
# 0      ZFAS1__p1__tile2__plus__peak1  NRF1__chr20__47895120     HepG2
# 8      DLEU1__p1__tile2__plus__peak2  NRF1__chr13__50656376     HepG2
# 1      DLEU1__p1__tile1__plus__peak1  NRF1__chr13__50656265     HepG2
# 3  LINC00467__p1__tile2__plus__peak3  NRF1__chr1__211556129     HepG2
# 0      FALEC__p1__tile2__plus__peak1  NRF1__chr1__150488212     HepG2
# 0      ZFAS1__p1__tile2__plus__peak1  NRF1__chr20__47895120      K562
#
#   all_chip_overlap cell_chip_overlap
# 0     ChIP_overlap      ChIP_overlap
# 8     ChIP_overlap      ChIP_overlap
# 1     ChIP_overlap      ChIP_overlap
# 3     ChIP_overlap      ChIP_overlap
# 0     ChIP_overlap      ChIP_overlap
# 0     ChIP_overlap      ChIP_overlap

# %% [markdown]
# ## same for fimo

# %%
fimo_uniq_motifs = sorted(list(all_fimo["motif"].unique()))
len(fimo_uniq_motifs)
# Out:
# 281

# %%
fimo_motifs_int = pd.DataFrame()
n_chip = 0
n_cell_chip = 0

for motif in fimo_uniq_motifs:
    print("=== %s ===" % motif)
    sub_df = all_fimo[all_fimo["motif"] == motif]
    
    # first check if these motifs overlap *any* chip peaks
    # sub_df = intersect_chip_files(sub_df, "%s/all.chip.bed.gz" % chip_dir, "any_chip_overlap")
    
    # force motif to upper
    motif_up = motif.upper()
    
    # see if that motif has been chipped at all
    if motif_up in chip_motifs:
        print("has been chipped")
        n_chip += 1

        sub_df = merge_and_intersect_chip_files(chip_files, motif_up, chip_dir, sub_df, "all_chip_overlap")
            
        # do both k562 & hepg2
        for cell, cell_chip_motifs, cell_chip_files in zip(["HepG2", "K562"], [hepg2_chip_motifs, k562_chip_motifs], [hepg2_chip_files, k562_chip_files]):
            cell_df = sub_df[sub_df["cell_type"] == cell]
            
            # now see if that motif has been chipped in cell type
            if motif_up in cell_chip_motifs:
                print("in %s" % cell)
                n_cell_chip += 1

                # find chip files and merge again
                cell_df = merge_and_intersect_chip_files(cell_chip_files, motif_up, chip_dir, cell_df, 
                                                         "cell_chip_overlap")
            else:
                cell_df["cell_chip_overlap"] = "no_ChIP"
            
            fimo_motifs_int = fimo_motifs_int.append(cell_df)
    else:
        sub_df["all_chip_overlap"] = "no_ChIP"
        sub_df["cell_chip_overlap"] = "no_ChIP"
        fimo_motifs_int = fimo_motifs_int.append(sub_df)
# Out:
# === ARNT::HIF1A ===
# === ATF4 ===
# === ATF7 ===
# === Arntl ===
# === Ascl2 ===
# === Atf1 ===
# has been chipped
# in K562
# === Atf3 ===
# has been chipped
# in HepG2
# in K562
# === BATF3 ===
# === BATF::JUN ===
# === Bach1::Mafk ===
# === Barhl1 ===
# === CDX1 ===
# === CDX2 ===
# === CEBPG ===
# === CREB1 ===
# has been chipped
# === CREB3 ===
# === CREB3L1 ===
# === CTCF ===
# has been chipped
# in HepG2
# in K562
# === CUX1 ===
# === CUX2 ===
# === Creb5 ===
# === Crem ===
# === Crx ===
# === DBP ===
# === Ddit3::Cebpa ===
# === Dlx4 ===
# === Dux ===
# === E2F4 ===
# has been chipped
# in K562
# === E2F6 ===
# has been chipped
# in K562
# === E2F7 ===
# === E2F8 ===
# === EBF1 ===
# has been chipped
# === EGR1 ===
# has been chipped
# in K562
# === EGR2 ===
# === EGR3 ===
# === EGR4 ===
# === EHF ===
# === ELF1 ===
# has been chipped
# in HepG2
# in K562
# === ELF3 ===
# === ELF4 ===
# === ELF5 ===
# === ELK1 ===
# has been chipped
# in K562
# === ELK3 ===
# === ELK4 ===
# has been chipped
# === EOMES ===
# === ERF ===
# === ERG ===
# === ESR2 ===
# === ETS1 ===
# has been chipped
# in K562
# === ETV1 ===
# === ETV2 ===
# === ETV3 ===
# === ETV4 ===
# === ETV5 ===
# === ETV6 ===
# === EWSR1-FLI1 ===
# === FEV ===
# === FIGLA ===
# === FLI1 ===
# === FOS ===
# has been chipped
# in K562
# === FOS::JUN ===
# === FOSL1 ===
# has been chipped
# in K562
# === FOSL2 ===
# has been chipped
# in HepG2
# === FOXC1 ===
# === FOXC2 ===
# === FOXD1 ===
# === FOXD2 ===
# === FOXF2 ===
# === FOXG1 ===
# === FOXH1 ===
# === FOXI1 ===
# === FOXL1 ===
# === FOXO3 ===
# === FOXO4 ===
# === FOXO6 ===
# === FOXP1 ===
# === FOXP3 ===
# === Foxd3 ===
# === Foxj2 ===
# === Foxj3 ===
# === Foxk1 ===
# === Foxo1 ===
# === GATA1::TAL1 ===
# === GCM1 ===
# === GCM2 ===
# === GLI2 ===
# === GLIS1 ===
# === GLIS2 ===
# === GLIS3 ===
# === GRHL1 ===
# === Gabpa ===
# has been chipped
# in HepG2
# in K562
# === Gfi1 ===
# === Gmeb1 ===
# === HEY1 ===
# === HEY2 ===
# === HIC2 ===
# === HINFP ===
# === HLF ===
# === HNF4G ===
# has been chipped
# in HepG2
# === HOXA13 ===
# === HOXB13 ===
# === HOXC13 ===
# === HOXD13 ===
# === HSF2 ===
# === Hes1 ===
# === Hic1 ===
# === ID4 ===
# === INSM1 ===
# === IRF1 ===
# has been chipped
# in K562
# === IRF2 ===
# === IRF7 ===
# === IRF8 ===
# === IRF9 ===
# === JDP2 ===
# === JDP2(var.2) ===
# === JUN ===
# has been chipped
# in HepG2
# in K562
# === JUN(var.2) ===
# === JUNB ===
# has been chipped
# in K562
# === JUND ===
# has been chipped
# in HepG2
# in K562
# === JUND(var.2) ===
# === KLF13 ===
# === KLF14 ===
# === KLF16 ===
# === KLF5 ===
# === Klf1 ===
# === Klf12 ===
# === Klf4 ===
# === MAF::NFE2 ===
# === MAFF ===
# has been chipped
# in HepG2
# in K562
# === MAFG ===
# === MEF2A ===
# has been chipped
# in K562
# === MEF2B ===
# === MEF2C ===
# has been chipped
# === MEF2D ===
# === MEIS1 ===
# === MEIS2 ===
# === MEIS3 ===
# === MGA ===
# === MSC ===
# === MTF1 ===
# === MYBL1 ===
# === MYF6 ===
# === MZF1(var.2) ===
# === Mafb ===
# === Mitf ===
# === Myb ===
# === Myc ===
# has been chipped
# in HepG2
# in K562
# === Myod1 ===
# === Myog ===
# === NFAT5 ===
# === NFATC1 ===
# has been chipped
# === NFATC2 ===
# === NFE2 ===
# has been chipped
# in K562
# === NFIA ===
# === NFIC::TLX1 ===
# === NFIL3 ===
# === NFIX ===
# === NFKB1 ===
# === NFYA ===
# has been chipped
# in K562
# === NFYB ===
# has been chipped
# in K562
# === NHLH1 ===
# === NR1H2::RXRA ===
# === NR2C2 ===
# has been chipped
# in HepG2
# in K562
# === NRF1 ===
# has been chipped
# in HepG2
# in K562
# === NRL ===
# === Nfe2l2 ===
# === Nr2e1 ===
# === Nr2f6 ===
# === Nr2f6(var.2) ===
# === Nr5a2 ===
# === ONECUT1 ===
# === ONECUT2 ===
# === ONECUT3 ===
# === PAX5 ===
# has been chipped
# === PHOX2A ===
# === PKNOX1 ===
# === PKNOX2 ===
# === PLAG1 ===
# === POU4F1 ===
# === PPARG ===
# === PRDM1 ===
# has been chipped
# === PROP1 ===
# === PROX1 ===
# === Pax2 ===
# === Phox2b ===
# === Pou5f1::Sox2 ===
# === Pparg::Rxra ===
# === RARA(var.2) ===
# === RARA::RXRA ===
# === REL ===
# === REST ===
# has been chipped
# in HepG2
# in K562
# === RORA ===
# === RORA(var.2) ===
# === RREB1 ===
# === RUNX1 ===
# === RUNX2 ===
# === RUNX3 ===
# has been chipped
# === RXRA::VDR ===
# === Rarb ===
# === Rarg ===
# === Rfx1 ===
# === SCRT2 ===
# === SMAD2::SMAD3::SMAD4 ===
# === SMAD3 ===
# === SNAI2 ===
# === SOX4 ===
# === SP1 ===
# has been chipped
# in HepG2
# in K562
# === SP2 ===
# has been chipped
# in HepG2
# in K562
# === SP3 ===
# === SP4 ===
# has been chipped
# === SP8 ===
# === SPDEF ===
# === SPI1 ===
# has been chipped
# in K562
# === SPIB ===
# === SPIC ===
# === SREBF1 ===
# === SREBF2 ===
# === SREBF2(var.2) ===
# === STAT1 ===
# has been chipped
# in K562
# === STAT1::STAT2 ===
# === STAT3 ===
# has been chipped
# === Sox2 ===
# === Sox6 ===
# === Spz1 ===
# === Srebf1(var.2) ===
# === Stat4 ===
# === Stat5a::Stat5b ===
# === Stat6 ===
# === TBP ===
# has been chipped
# in HepG2
# in K562
# === TBR1 ===
# === TBX1 ===
# === TBX15 ===
# === TBX2 ===
# === TBX20 ===
# === TBX21 ===
# === TBX4 ===
# === TBX5 ===
# === TCF3 ===
# has been chipped
# === TCF4 ===
# === TCF7L2 ===
# has been chipped
# in HepG2
# === TEF ===
# === TFAP2A ===
# has been chipped
# === TFAP2A(var.2) ===
# === TFAP2A(var.3) ===
# === TFAP2B ===
# === TFAP2B(var.2) ===
# === TFAP2B(var.3) ===
# === TFAP2C ===
# has been chipped
# === TFAP2C(var.2) ===
# === TFAP2C(var.3) ===
# === TFAP4 ===
# === TFCP2 ===
# === TFEC ===
# === TGIF1 ===
# === TGIF2 ===
# === THAP1 ===
# has been chipped
# in K562
# === Tcf12 ===
# has been chipped
# in HepG2
# === Tcf21 ===
# === Tcfl5 ===
# === Twist2 ===
# === USF1 ===
# has been chipped
# in HepG2
# in K562
# === USF2 ===
# has been chipped
# in HepG2
# in K562
# === Vdr ===
# === XBP1 ===
# === YY1 ===
# has been chipped
# in HepG2
# in K562
# === YY2 ===
# === ZBTB18 ===
# === ZBTB33 ===
# has been chipped
# in HepG2
# in K562
# === ZBTB7A ===
# has been chipped
# in HepG2
# in K562
# === ZBTB7B ===
# === ZBTB7C ===
# === ZEB1 ===
# has been chipped
# === ZIC1 ===
# === ZIC3 ===
# === ZIC4 ===
# === ZNF143 ===
# has been chipped
# in K562
# === ZNF263 ===
# has been chipped
# in K562
# === ZNF410 ===
# === ZNF740 ===
# === Zfx ===
# === Znf423 ===

# %%
fimo_motifs_int[fimo_motifs_int["motif"] == "NRF1"].head()
# Out:
#     tile_chr  motif_start  motif_end motif    score strand  \
# 131     chr9     21994467   21994478  NRF1  14.9455      -
# 156     chr9     21994460   21994471  NRF1  12.6727      +
# 179     chr9     21994489   21994500  NRF1  11.5455      +
# 248     chr9     21994528   21994539  NRF1  14.9455      +
# 273     chr9     21994535   21994546  NRF1  12.6727      -
#
#                                                   gene                    id  \
# 131  FLIPPED__mrna.flip.antisense__p1@CDKN2A__chr9:...  NRF1__chr9__21994467
# 156  FLIPPED__mrna.flip.antisense__p1@CDKN2A__chr9:...  NRF1__chr9__21994460
# 179  FLIPPED__mrna.flip.antisense__p1@CDKN2A__chr9:...  NRF1__chr9__21994489
# 248  WILDTYPE_BUT_HAS_SNP__mrna.flip.sense__p1@CDKN...  NRF1__chr9__21994528
# 273  WILDTYPE_BUT_HAS_SNP__mrna.flip.sense__p1@CDKN...  NRF1__chr9__21994535
#
#     cell_type all_chip_overlap cell_chip_overlap
# 131     HepG2       no_overlap        no_overlap
# 156     HepG2       no_overlap        no_overlap
# 179     HepG2       no_overlap        no_overlap
# 248     HepG2       no_overlap        no_overlap
# 273     HepG2       no_overlap        no_overlap

# %% [markdown]
# ## 4. find numbers

# %%
cell_results = pd.pivot_table(all_motifs_int, values="id", index="cell_chip_overlap", columns="cell_type",
                              aggfunc="count").reset_index()
cell_results
# Out:
# cell_type cell_chip_overlap  HepG2  K562
# 0              ChIP_overlap     32    23
# 1                   no_ChIP    544   173
# 2                no_overlap     42    18

# %%
all_results = pd.pivot_table(all_motifs_int, values="id", index="all_chip_overlap", columns="cell_type",
                             aggfunc="count").reset_index()
all_results
# Out:
# cell_type all_chip_overlap  HepG2  K562
# 0             ChIP_overlap     92    37
# 1                  no_ChIP    467   157
# 2               no_overlap     59    20

# %%
cell_results_melt = pd.melt(cell_results, id_vars="cell_chip_overlap")
all_results_melt = pd.melt(all_results, id_vars="all_chip_overlap")

cell_results_melt = cell_results_melt[cell_results_melt["cell_chip_overlap"] != "no_ChIP"]
all_results_melt = all_results_melt[all_results_melt["all_chip_overlap"] != "no_ChIP"]

all_results_melt.head()
# Out:
#   all_chip_overlap cell_type  value
# 0     ChIP_overlap     HepG2     92
# 2       no_overlap     HepG2     59
# 3     ChIP_overlap      K562     37
# 5       no_overlap      K562     20

# %%
cell_results_counts = cell_results_melt.groupby("cell_type")["value"].agg("sum").reset_index()
cell_results_melt = cell_results_melt.merge(cell_results_counts, on="cell_type", suffixes=("_count", "_total"))
cell_results_melt["percent"] = (cell_results_melt["value_count"]/cell_results_melt["value_total"])*100

all_results_counts = all_results_melt.groupby("cell_type")["value"].agg("sum").reset_index()
all_results_melt = all_results_melt.merge(all_results_counts, on="cell_type", suffixes=("_count", "_total"))
all_results_melt["percent"] = (all_results_melt["value_count"]/all_results_melt["value_total"])*100

all_results_melt.head()
# Out:
#   all_chip_overlap cell_type  value_count  value_total    percent
# 0     ChIP_overlap     HepG2           92          151  60.927152
# 1       no_overlap     HepG2           59          151  39.072848
# 2     ChIP_overlap      K562           37           57  64.912281
# 3       no_overlap      K562           20           57  35.087719

# %%
cell_results_melt = cell_results_melt[cell_results_melt["cell_chip_overlap"] == "ChIP_overlap"]
cell_results_melt["type"] = "cell-type ChIP"
cell_results_melt = cell_results_melt[["type", "cell_type", "percent"]]

all_results_melt = all_results_melt[all_results_melt["all_chip_overlap"] == "ChIP_overlap"]
all_results_melt["type"] = "all ChIP"
all_results_melt = all_results_melt[["type", "cell_type", "percent"]]

results_melt = cell_results_melt.append(all_results_melt)
results_melt
# Out:
#              type cell_type    percent
# 0  cell-type ChIP     HepG2  43.243243
# 2  cell-type ChIP      K562  56.097561
# 0        all ChIP     HepG2  60.927152
# 2        all ChIP      K562  64.912281

# %%
sns.barplot(data=results_melt, x="type", y="percent", hue="cell_type", order=["all ChIP", "cell-type ChIP"])
plt.xlabel("")
plt.ylabel("% of motifs that overlap a ChIP peak")
plt.ylim((0, 100))
# Out:
# (0, 100)

# %%
figs_dir = "figs/0__overlap_bar"
# !mkdir -p $figs_dir

plt.figure(figsize=(1.8, 1.9))
sns.barplot(data=results_melt[results_melt["type"] == "all ChIP"], 
            x="cell_type", y="percent", color=sns.color_palette("Set2")[0])
plt.xlabel("")
plt.ylabel("% of motifs that overlap a ChIP peak")
plt.ylim((0, 100))
plt.savefig("%s/all_chip_overlap.pdf" % figs_dir, dpi="figure", bbox_inches="tight")

# %%
all_motifs_int_allchip = all_motifs_int[all_motifs_int["all_chip_overlap"] != "no_ChIP"]
ax = sns.boxplot(data=all_motifs_int_allchip, x="cell_type", y="score", hue="all_chip_overlap",
                 flierprops=flierprops, palette={"ChIP_overlap": sns.color_palette()[1],
                                                 "no_overlap": "gray"})
mimic_r_boxplot(ax)
plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# ## same with fimo

# %%
cell_results = pd.pivot_table(fimo_motifs_int, values="id", index="cell_chip_overlap", columns="cell_type",
                              aggfunc="count").reset_index()
cell_results
# Out:
# cell_type cell_chip_overlap  HepG2  K562
# 0              ChIP_overlap     61   132
# 1                   no_ChIP   1475  1235
# 2                no_overlap    223   392

# %%
all_results = pd.pivot_table(fimo_motifs_int, values="id", index="all_chip_overlap", columns="cell_type",
                             aggfunc="count").reset_index()
all_results
# Out:
# cell_type all_chip_overlap  HepG2  K562
# 0             ChIP_overlap    256   256
# 1                  no_ChIP   1140  1140
# 2               no_overlap    363   363

# %%
cell_results_melt = pd.melt(cell_results, id_vars="cell_chip_overlap")
all_results_melt = pd.melt(all_results, id_vars="all_chip_overlap")

cell_results_melt = cell_results_melt[cell_results_melt["cell_chip_overlap"] != "no_ChIP"]
all_results_melt = all_results_melt[all_results_melt["all_chip_overlap"] != "no_ChIP"]

all_results_melt.head()
# Out:
#   all_chip_overlap cell_type  value
# 0     ChIP_overlap     HepG2    256
# 2       no_overlap     HepG2    363
# 3     ChIP_overlap      K562    256
# 5       no_overlap      K562    363

# %%
cell_results_counts = cell_results_melt.groupby("cell_type")["value"].agg("sum").reset_index()
cell_results_melt = cell_results_melt.merge(cell_results_counts, on="cell_type", suffixes=("_count", "_total"))
cell_results_melt["percent"] = (cell_results_melt["value_count"]/cell_results_melt["value_total"])*100

all_results_counts = all_results_melt.groupby("cell_type")["value"].agg("sum").reset_index()
all_results_melt = all_results_melt.merge(all_results_counts, on="cell_type", suffixes=("_count", "_total"))
all_results_melt["percent"] = (all_results_melt["value_count"]/all_results_melt["value_total"])*100

all_results_melt.head()
# Out:
#   all_chip_overlap cell_type  value_count  value_total    percent
# 0     ChIP_overlap     HepG2          256          619  41.357027
# 1       no_overlap     HepG2          363          619  58.642973
# 2     ChIP_overlap      K562          256          619  41.357027
# 3       no_overlap      K562          363          619  58.642973

# %%
cell_results_melt = cell_results_melt[cell_results_melt["cell_chip_overlap"] == "ChIP_overlap"]
cell_results_melt["type"] = "cell-type ChIP"
cell_results_melt = cell_results_melt[["type", "cell_type", "percent"]]

all_results_melt = all_results_melt[all_results_melt["all_chip_overlap"] == "ChIP_overlap"]
all_results_melt["type"] = "all ChIP"
all_results_melt = all_results_melt[["type", "cell_type", "percent"]]

results_melt = cell_results_melt.append(all_results_melt)
results_melt
# Out:
#              type cell_type    percent
# 0  cell-type ChIP     HepG2  21.478873
# 2  cell-type ChIP      K562  25.190840
# 0        all ChIP     HepG2  41.357027
# 2        all ChIP      K562  41.357027

# %%
sns.barplot(data=results_melt, x="type", y="percent", hue="cell_type", order=["all ChIP", "cell-type ChIP"])
plt.xlabel("")
plt.ylabel("% of motifs that overlap a ChIP peak")
plt.ylim((0, 100))
# Out:
# (0, 100)

# %%
figs_dir = "figs/0__overlap_bar"
# !mkdir -p $figs_dir

plt.figure(figsize=(1.8, 1.9))
sns.barplot(data=results_melt[results_melt["type"] == "all ChIP"], 
            x="cell_type", y="percent", color=sns.color_palette("Set2")[0])
plt.xlabel("")
plt.ylabel("% of motifs that overlap a ChIP peak")
plt.ylim((0, 100))
plt.savefig("%s/all_chip_overlap.fimo.pdf" % figs_dir, dpi="figure", bbox_inches="tight")

# %%
all_motifs_int_allchip = all_motifs_int[all_motifs_int["all_chip_overlap"] != "no_ChIP"]
ax = sns.boxplot(data=all_motifs_int_allchip, x="cell_type", y="score", hue="all_chip_overlap",
                 flierprops=flierprops, palette={"ChIP_overlap": sns.color_palette()[1],
                                                 "no_overlap": "gray"})
mimic_r_boxplot(ax)
plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# ## 5. correlate # of motifs w/ ref tile activity

# %%
hepg2_del_files[0:5]
# Out:
# ['CRNDE__p1__tile1__plus__loss.loss_score_data.txt',
#  'CRNDE__p1__tile2__plus__loss.loss_score_data.txt',
#  'ANRIL__p1__tile1__minus__loss.loss_score_data.txt',
#  'ZFAS1__p1__tile2__plus__loss.loss_score_data.txt',
#  'ZFAS1__p1__tile1__plus__loss.loss_score_data.txt']

# %%
hepg2_dict = {}
k562_dict = {}
for del_dir, file_list, d in zip([hepg2_del_dir, k562_del_dir], [hepg2_del_files, k562_del_files], 
                                 [hepg2_dict, k562_dict]):
    for f in file_list:
        sp = f.split("__")
        seq_name = "%s__%s__%s__%s" % (sp[0], sp[1], sp[2], sp[3])
        df = pd.read_table("%s/%s" % (del_dir, f), sep="\t")
        wt_activ = df["wt_activ"].iloc[0]
        wt_class = df["wt_class"].iloc[0]
        d[seq_name] = [wt_activ, wt_class]

# %%
hepg2_activ = pd.DataFrame.from_dict(hepg2_dict, orient="index").reset_index()
hepg2_activ.columns = ["seq_name", "activ", "class"]

k562_activ = pd.DataFrame.from_dict(k562_dict, orient="index").reset_index()
k562_activ.columns = ["seq_name", "activ", "class"]

hepg2_activ.head()
# Out:
#                   seq_name     activ       class
# 0   CRNDE__p1__tile1__plus -0.045059  sig active
# 1   CRNDE__p1__tile2__plus  0.041739  sig active
# 2  ANRIL__p1__tile1__minus -0.123673  sig active
# 3   ZFAS1__p1__tile2__plus  4.731591  sig active
# 4   ZFAS1__p1__tile1__plus -0.021557  sig active

# %%
hepg2_all_motifs["seq_name"] = hepg2_all_motifs["gene"].str.split("__", expand=True)[0] + "__" + hepg2_all_motifs["gene"].str.split("__", expand=True)[1] + "__" + hepg2_all_motifs["gene"].str.split("__", expand=True)[2] + "__" + hepg2_all_motifs["gene"].str.split("__", expand=True)[3]
k562_all_motifs["seq_name"] = k562_all_motifs["gene"].str.split("__", expand=True)[0] + "__" + k562_all_motifs["gene"].str.split("__", expand=True)[1] + "__" + k562_all_motifs["gene"].str.split("__", expand=True)[2] + "__" + k562_all_motifs["gene"].str.split("__", expand=True)[3]

# %%
hepg2_n_motifs = hepg2_all_motifs.groupby("seq_name")["id"].agg("count").reset_index()
k562_n_motifs = k562_all_motifs.groupby("seq_name")["id"].agg("count").reset_index()
hepg2_n_motifs.head()
# Out:
#                    seq_name  id
# 0    ANRIL__p1__tile2__plus  35
# 1  CDKN2A__p1__tile2__minus   9
# 2    DLEU1__p1__tile1__plus   2
# 3    DLEU1__p1__tile2__plus   5
# 4    FALEC__p1__tile2__plus   3

# %%
hepg2_n_motifs = hepg2_activ.merge(hepg2_n_motifs, on="seq_name", how="left")
k562_n_motifs = k562_activ.merge(k562_n_motifs, on="seq_name", how="left")
hepg2_n_motifs.head()
# Out:
#                   seq_name     activ       class    id
# 0   CRNDE__p1__tile1__plus -0.045059  sig active   NaN
# 1   CRNDE__p1__tile2__plus  0.041739  sig active   NaN
# 2  ANRIL__p1__tile1__minus -0.123673  sig active   NaN
# 3   ZFAS1__p1__tile2__plus  4.731591  sig active  20.0
# 4   ZFAS1__p1__tile1__plus -0.021557  sig active   NaN

# %%
hepg2_n_motifs.fillna(0, inplace=True)
k562_n_motifs.fillna(0, inplace=True)

# %%
from scipy.stats import spearmanr

# %%
hepg2_n_motifs[hepg2_n_motifs["class"] != "sig_active"]
# Out:
#                                 seq_name     activ       class    id
# 0                 CRNDE__p1__tile1__plus -0.045059  sig active   0.0
# 1                 CRNDE__p1__tile2__plus  0.041739  sig active   0.0
# 2                ANRIL__p1__tile1__minus -0.123673  sig active   0.0
# 3                 ZFAS1__p1__tile2__plus  4.731591  sig active  20.0
# 4                 ZFAS1__p1__tile1__plus -0.021557  sig active   0.0
# 5   enhancer_LINC_PINT__pX__tile1__minus  0.060140  sig active  33.0
# 6               CDKN2A__p1__tile1__minus  0.405311  sig active   0.0
# 7                  PVT1__p1__tile2__plus  0.539192  sig active   0.0
# 8                CDKN2A__p1__tile1__plus -0.440901  sig active   0.0
# 9                 GAS5__p1__tile1__minus  0.198671  sig active   0.0
# 10                GAS5__p1__tile2__minus  4.739875  sig active  92.0
# 11              HOTAIR__p1__tile2__minus  0.245950  sig active  33.0
# 13                DLEU1__p1__tile2__plus  0.808106  sig active   5.0
# 14                DLEU1__p1__tile1__plus  0.571308  sig active   2.0
# 15               ANRIL__p1__tile2__minus -0.080675  sig active   0.0
# 16               CDKN2A__p1__tile2__plus -0.107400  sig active   0.0
# 17                 MEG3__p1__tile2__plus  2.730831  sig active  16.0
# 18                 PVT1__p1__tile1__plus  0.551804  sig active   0.0
# 19              SAMMSON__p1__tile2__plus  2.235864  sig active  50.0
# 20     enhancer_MALAT1__pX__tile1__minus -0.116371  sig active   0.0
# 21     enhancer_MALAT1__pX__tile2__minus  3.202182  sig active   0.0
# 22            LINC00467__p1__tile1__plus  1.142243  sig active  25.0
# 23            LINC00467__p1__tile2__plus  2.829684  sig active   9.0
# 24              CDKN2A__p1__tile2__minus -0.217581  sig active   9.0
# 26                NEAT1__p1__tile2__plus -0.125922  sig active  51.0
# 27              LUCAT1__p1__tile2__minus  2.044930  sig active  23.0
# 28                ANRIL__p1__tile2__plus -0.138935  sig active  35.0
# 29               FENDRR__p1__tile1__plus  0.038944  sig active   0.0
# 30      enhancer_NEAT1__pX__tile2__minus  0.024331  sig active   8.0
# 31                TERC__p1__tile2__minus  1.114489  sig active  32.0
# 32                  JPX__p1__tile2__plus  1.700021  sig active  18.0
# 33              FENDRR__p1__tile2__minus  0.209651  sig active   0.0
# 34                  JPX__p1__tile1__plus  0.842822  sig active   0.0
# 35           LINC_PINT__p2__tile1__minus  1.416947  sig active   8.0
# 36                 FOXF1__p__tile1__plus  0.131869  sig active   0.0
# 37               MALAT1__p4__tile1__plus -0.115681  sig active   0.0
# 38               MALAT1__p4__tile2__plus -0.301220  sig active   0.0
# 39                 FOXF1__p__tile2__plus  0.504326  sig active   0.0
# 41               MALAT1__p1__tile1__plus  1.299851  sig active  22.0
# 42               CRNDE__p1__tile1__minus  0.018798  sig active   0.0
# 43                FALEC__p1__tile2__plus  1.763648  sig active   3.0
# 44       enhancer_TERC__pX__tile2__minus -0.504331  sig active  27.0
# 45               CRNDE__p1__tile2__minus  0.512738  sig active   0.0
# 46               ZBTB37__p1__tile1__plus -0.117565  sig active   0.0
# 47                TERC__p1__tile1__minus  1.980673  sig active  53.0
# 48               ZBTB37__p1__tile2__plus  3.719645  sig active  44.0

# %%
figs_dir = "figs/1__activ_n_motifs_corr"
# !mkdir -p $figs_dir

g = sns.jointplot(data=hepg2_n_motifs, x="activ", y="id", kind="reg", space=0, size=2.2, stat_func=spearmanr, 
                  marginal_kws={"hist": True, "kde": False, "bins": 10}, color="darkgrey", scatter_kws={"s": 25},
                  xlim=(-1, 6), ylim=(-10, 90))
g.set_axis_labels("reference activity", "# motifs")

plt.savefig("%s/HepG2_corr.pdf" % (figs_dir), dpi="figure", bbox_inches="tight")

# %%
g = sns.jointplot(data=k562_n_motifs, x="activ", y="id", kind="reg", space=0, size=2.2, stat_func=spearmanr, 
                  marginal_kws={"hist": True, "kde": False, "bins": 10}, color="darkgrey", scatter_kws={"s": 25},
                  xlim=(-1, 6), ylim=(-10, 90))
g.set_axis_labels("reference activity", "# motifs")

plt.savefig("%s/K562_corr.pdf" % (figs_dir), dpi="figure", bbox_inches="tight")

# %%
x = np.random.normal(size=1000)

fig = plt.figure(figsize=(3, 1))
sns.distplot(x, color="gray")
plt.xlabel("shuffled motif scores")
plt.ylabel("density")
plt.axvline(x=2.3, color="black", linestyle="dashed")
fig.savefig("%s/null_small.pdf" % figs_dir, dpi="figure", bbox_inches="tight")
